# %%
# pip install yfinance

# %%
import pandas as pd
import yfinance as yf

# %%
sp500url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
data_table = pd.read_html(sp500url)

# %%
data_table
# Out:
# [    Symbol             Security             GICS Sector  \
#  0      MMM                   3M             Industrials
#  1      AOS          A. O. Smith             Industrials
#  2      ABT  Abbott Laboratories             Health Care
#  3     ABBV               AbbVie             Health Care
#  4      ACN            Accenture  Information Technology
#  ..     ...                  ...                     ...
#  498    XYL           Xylem Inc.             Industrials
#  499    YUM          Yum! Brands  Consumer Discretionary
#  500   ZBRA   Zebra Technologies  Information Technology
#  501    ZBH        Zimmer Biomet             Health Care
#  502    ZTS               Zoetis             Health Care
#
#                                  GICS Sub-Industry    Headquarters Location  \
#  0                        Industrial Conglomerates    Saint Paul, Minnesota
#  1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
len(data_table)
# Out:
# 2

# %%
data_table[0]
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
tickers = data_table[0]['Symbol'].tolist()
tickers = [ticker.replace('.', '-') for ticker in tickers]

# %%
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'ABNB',
#  'AKAM',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'APO',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BAX',
#  'BDX',
#  'BRK-B',
#  'BBY',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BX',
#  'BK',
#  'BA',
#  'BKNG',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF-B',
#  'BLDR',
#  'BG',
#  'BXP',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'COR',
#  'CNC',
#  'CNP',
#  'CF',
#  'CRL',
# ...

# %%
len(tickers)
# Out:
# 503

# %%
snp_prices = yf.download(tickers, start='2024-04-01', end='2025-04-01')['Close']
# Out:
# [*********************100%***********************]  503 of 503 completed

# %%
snp_prices
# Out:
# Ticker               A        AAPL        ABBV        ABNB         ABT  \
# Date
# 2024-04-01  144.484848  169.230911  174.406769  163.369995  109.851318
# 2024-04-02  143.105087  168.046509  174.339249  160.110001  109.782722
# 2024-04-03  142.668350  168.852707  171.097336  159.339996  109.057503
# 2024-04-04  140.296005  168.026611  161.998764  158.839996  107.910873
# 2024-04-05  143.055466  168.783035  164.024963  161.770004  108.979095
# ...                ...         ...         ...         ...         ...
# 2025-03-25  120.254517  223.750000  201.339996  129.880005  125.599998
# 2025-03-26  119.645813  221.529999  201.300003  128.639999  126.610001
# 2025-03-27  118.717781  223.850006  202.720001  125.650002  131.350006
# 2025-03-28  116.442619  217.899994  205.289993  120.690002  130.820007
# 2025-03-31  116.732002  222.130005  209.520004  119.459999  132.649994
#
# Ticker           ACGL         ACN        ADBE         ADI        ADM  ...  \
# ...

# %%
snp_prices.isna().any()
# Out:
# Ticker
# A       False
# AAPL    False
# ABBV    False
# ABNB    False
# ABT     False
#         ...
# XYL     False
# YUM     False
# ZBH     False
# ZBRA    False
# ZTS     False
# Length: 503, dtype: bool

# %%
snp_prices.loc[:, snp_prices.isna().any()]
# Out:
# Ticker             SW
# Date
# 2024-04-01        NaN
# 2024-04-02        NaN
# 2024-04-03        NaN
# 2024-04-04        NaN
# 2024-04-05        NaN
# ...               ...
# 2025-03-25  45.570000
# 2025-03-26  45.279999
# 2025-03-27  45.400002
# 2025-03-28  44.509998
# 2025-03-31  45.060001
#
# [251 rows x 1 columns]

# %%
# Xử lý dữ liệu thiếu
snp_prices.bfill(inplace=True)

# %%
len(snp_prices.columns)
# Out:
# 503

# %%
snp_prices
# Out:
# Ticker               A        AAPL        ABBV        ABNB         ABT  \
# Date
# 2024-04-01  144.484848  169.230911  174.406769  163.369995  109.851318
# 2024-04-02  143.105087  168.046509  174.339249  160.110001  109.782722
# 2024-04-03  142.668350  168.852707  171.097336  159.339996  109.057503
# 2024-04-04  140.296005  168.026611  161.998764  158.839996  107.910873
# 2024-04-05  143.055466  168.783035  164.024963  161.770004  108.979095
# ...                ...         ...         ...         ...         ...
# 2025-03-25  120.254517  223.750000  201.339996  129.880005  125.599998
# 2025-03-26  119.645813  221.529999  201.300003  128.639999  126.610001
# 2025-03-27  118.717781  223.850006  202.720001  125.650002  131.350006
# 2025-03-28  116.442619  217.899994  205.289993  120.690002  130.820007
# 2025-03-31  116.732002  222.130005  209.520004  119.459999  132.649994
#
# Ticker           ACGL         ACN        ADBE         ADI        ADM  ...  \
# ...

# %%
# Xuất dữ liệu ra tệp CSV
snp_prices.to_csv('snp_prices.csv', index=True)
