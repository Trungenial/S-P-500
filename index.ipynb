# %%
# pip install yfinance

# %%
import pandas as pd
import yfinance as yf

# %%
sp500url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
data_table = pd.read_html(sp500url)

# %%
data_table
# Out:
# [    Symbol             Security             GICS Sector  \
#  0      MMM                   3M             Industrials
#  1      AOS          A. O. Smith             Industrials
#  2      ABT  Abbott Laboratories             Health Care
#  3     ABBV               AbbVie             Health Care
#  4      ACN            Accenture  Information Technology
#  ..     ...                  ...                     ...
#  498    XYL           Xylem Inc.             Industrials
#  499    YUM          Yum! Brands  Consumer Discretionary
#  500   ZBRA   Zebra Technologies  Information Technology
#  501    ZBH        Zimmer Biomet             Health Care
#  502    ZTS               Zoetis             Health Care
#
#                                  GICS Sub-Industry    Headquarters Location  \
#  0                        Industrial Conglomerates    Saint Paul, Minnesota
#  1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
len(data_table)
# Out:
# 2

# %%
data_table[0]
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
tickers = data_table[0]['Symbol'].tolist()

# %%
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'ABNB',
#  'AKAM',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'APO',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BX',
#  'BK',
#  'BA',
#  'BKNG',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BLDR',
#  'BG',
#  'BXP',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'COR',
#  'CNC',
#  'CNP',
#  'CF',
#  'CRL',
# ...

# %%
len(tickers)
# Out:
# 503

# %%
yf.download('MMM', start='2022-05-02', end='2022-05-05')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker             MMM         MMM         MMM         MMM      MMM
# Date
# 2022-05-02  107.168999  108.336831  105.604541  106.140715  4445891
# 2022-05-03  108.762825  109.328381  107.176338  107.389334  3000405
# 2022-05-04  113.279930  113.595756  108.615938  109.438563  4418263

# %%
snp_prices = yf.download(tickers, start='2022-05-02', end='2022-05-05')['Close']
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 9 Failed downloads:
# ['BF.B']: YFPricesMissingError('possibly delisted; no price data found  (1d 2022-05-02 -> 2022-05-05)')
# ['SW', 'SOLV', 'GEHC', 'VLTO', 'GEV', 'KVUE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2022-05-02 -> 2022-05-05) (Yahoo error = "Data doesn\'t exist for startDate = 1651464000, endDate = 1651723200")')
# ['TKO']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')

# %%
snp_prices
# Out:
# Ticker               A        AAPL        ABBV        ABNB         ABT  \
# Date
# 2022-05-02  117.054100  155.441299  133.220673  152.779999  106.904831
# 2022-05-03  119.824554  156.937042  134.779297  145.000000  106.525826
# 2022-05-04  123.642509  163.372803  136.572128  156.179993  109.624115
#
# Ticker           ACGL         ACN        ADBE         ADI        ADM  ...  \
# Date                                                                  ...
# 2022-05-02  43.627224  292.744781  407.290009  149.849060  82.199532  ...
# 2022-05-03  44.150219  292.956207  407.579987  150.531281  82.613716  ...
# 2022-05-04  44.987011  302.605469  423.350006  156.121597  83.893066  ...
#
# Ticker             WTW         WY       WYNN        XEL        XOM        XYL  \
# Date
# 2022-05-02  202.909943  36.125656  70.185341  65.741493  77.882805  78.887749
# 2022-05-03  205.318192  37.135902  70.165779  65.252983  79.487152  79.408333
# ...

# %%
snp_prices.isna().any()
# Out:
# Ticker
# A       False
# AAPL    False
# ABBV    False
# ABNB    False
# ABT     False
#         ...
# XYL     False
# YUM     False
# ZBH     False
# ZBRA    False
# ZTS     False
# Length: 503, dtype: bool

# %%
snp_prices.loc[:, snp_prices.isna().any()]
# Out:
# Ticker      BF.B  BRK.B  GEHC  GEV  KVUE  SOLV  SW  TKO  VLTO
# Date
# 2022-05-02   NaN    NaN   NaN  NaN   NaN   NaN NaN  NaN   NaN
# 2022-05-03   NaN    NaN   NaN  NaN   NaN   NaN NaN  NaN   NaN
# 2022-05-04   NaN    NaN   NaN  NaN   NaN   NaN NaN  NaN   NaN

# %%
yf.download('BF-B')['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker           BF-B
# Date
# 1980-03-17   0.184985
# 1980-03-18   0.184985
# 1980-03-19   0.187460
# 1980-03-20   0.188078
# 1980-03-21   0.185603
# ...               ...
# 2025-03-31  33.939999
# 2025-04-01  33.500000
# 2025-04-02  34.509998
# 2025-04-03  32.910000
# 2025-04-04  32.020000
#
# [11357 rows x 1 columns]

# %%
yf.download('BRK-B')['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker           BRK-B
# Date
# 1996-05-09   23.200001
# 1996-05-10   24.000000
# 1996-05-13   23.900000
# 1996-05-14   23.600000
# 1996-05-15   23.200001
# ...                ...
# 2025-03-31  532.580017
# 2025-04-01  532.989990
# 2025-04-02  537.719971
# 2025-04-03  530.159973
# 2025-04-04  493.540009
#
# [7274 rows x 1 columns]

# %%
for i in range(len(tickers)):
    if tickers[i] == 'BRK.B':
        tickers[i] = 'BRK-B'
    elif tickers[i] == 'BF.B':
        tickers[i] = 'BF-B'

# %%
'BF-B' in tickers
# Out:
# True

# %%
'BRK-B' in tickers
# Out:
# True

# %%
snp_prices = yf.download(tickers, start='2024-09-02', end = '2024-10-05')['Close']
# Out:
# [*********************100%***********************]  503 of 503 completed

# %%
snp_prices[['BRK-B', 'BF-B']]
# Out:
# Ticker           BRK-B       BF-B
# Date
# 2024-09-03  476.829987  45.331215
# 2024-09-04  478.570007  44.718231
# 2024-09-05  464.920013  44.708347
# 2024-09-06  459.420013  44.629250
# 2024-09-09  459.609985  45.815674
# 2024-09-10  458.920013  45.064274
# 2024-09-11  453.100006  45.054386
# 2024-09-12  450.869995  45.568501
# 2024-09-13  447.609985  45.934315
# 2024-09-16  451.779999  46.092503
# 2024-09-17  456.679993  46.507755
# 2024-09-18  456.600006  47.150394
# 2024-09-19  459.709991  47.219601
# 2024-09-20  455.309998  45.845333
# 2024-09-23  454.980011  46.507755
# 2024-09-24  454.559998  46.369339
# 2024-09-25  452.359985  45.479519
# 2024-09-26  454.179993  47.031757
# 2024-09-27  457.470001  47.793045
# 2024-09-30  460.260010  48.643314
# 2024-10-01  457.410004  48.188519
# 2024-10-02  456.670013  47.783157
# 2024-10-03  452.959991  47.061413
# 2024-10-04  461.970001  46.824131

# %%
len(snp_prices.columns)
# Out:
# 503

# %%
snp_prices
# Out:
# Ticker               A        AAPL        ABBV        ABNB         ABT  \
# Date
# 2024-09-03  138.189590  222.280777  194.291641  114.980003  113.526405
# 2024-09-04  137.394028  220.365005  193.623322  115.209999  113.268974
# 2024-09-05  137.592911  221.891632  189.544662  116.160004  111.981819
# 2024-09-06  136.439331  220.335083  190.075378  114.279999  112.734306
# 2024-09-09  137.324417  220.424866  193.043457  116.360001  115.278900
# 2024-09-10  137.264740  219.626633  195.923111  115.120003  115.952171
# 2024-09-11  137.931030  222.171021  191.244934  115.959999  115.447212
# 2024-09-12  135.633820  222.280777  190.684738  117.360001  115.674950
# 2024-09-13  136.548737  222.011383  190.871460  117.750000  115.249199
# 2024-09-16  137.543182  215.844955  192.365326  117.550003  116.467033
# 2024-09-17  137.582962  216.313904  190.124527  122.120003  116.962090
# 2024-09-18  138.239304  220.205353  189.623291  122.419998  113.744217
# ...
